# %%
# Nescessary imports

# %matplotlib inline

# supress warnings
import warnings
warnings.filterwarnings('ignore')

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' # supress tensorflow warnings

# import libraries
import sys
import random
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from keras.optimizers import Adadelta
from sklearn.model_selection import train_test_split

from yahoo_fin import stock_info as si
from datetime import datetime
from datetime import timedelta

# set random seed
random.seed(42)

# %%
ticker_list = ['aapl', 'msft', 'nflx', 'amzn', 'tsla', 'meta', 'googl']
history_dfs = {}
for ticker in ticker_list:
    history_dfs[ticker] = si.get_data(ticker, start_date='01/01/2010', end_date='01/01/2020', index_as_date = True, interval="1wk")

# %%
history_dfs['aapl'].head()
# Out:
#                 open      high       low     close  adjclose      volume  \
# 2010-01-01  7.622500  7.699643  7.466071  7.520714  6.392177  2124925600
# 2010-01-08  7.510714  7.607143  7.289286  7.479643  6.357269  2543086000
# 2010-01-15  7.533214  7.698214  7.352500  7.431071  6.315984  2544382400
# 2010-01-22  7.385000  7.632500  7.041429  7.117500  6.049468  6710648000
# 2010-01-29  7.181429  7.221429  6.794643  6.858929  5.829698  4067151200
#
#            ticker
# 2010-01-01   AAPL
# 2010-01-08   AAPL
# 2010-01-15   AAPL
# 2010-01-22   AAPL
# 2010-01-29   AAPL

# %%
tickers_dow = si.tickers_dow()
history_dfs_dow = {}
for ticker in tickers_dow:
    history_dfs_dow[ticker] = si.get_data(ticker, start_date='01/01/2010', end_date='01/01/2020', index_as_date = True, interval="1wk")
